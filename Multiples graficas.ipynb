# %% [markdown]
# # Multiples Gráficas

# %% [markdown]
# * Comprar Curvas
# * Matching
# * Donde hacen matching
# * Estan correlacionados

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib
plt.ioff()
# Out:
# Using matplotlib backend: Qt5Agg

# %%
# %matplotlib inline
x = np.linspace(0,2 * np.pi,100)
Ya = np.sin(x)
Yb = np.cos(x)
plt.plot(x,Ya)
plt.plot(x,Yb)
#plt.show()
#plt.ion()

# %% [markdown]
# # Renderizar
#
# * Que y cuando renderizar

# %%
def plotPendiente(X,Y):
    Xs = X[1:] - X[:-1]
    Ys = Y[1:] - Y[:-1]
    plt.plot(X[1:],Ys/Xs)

# %%
X = np.linspace(-3,3,100)
Y = np.exp(-X ** 2)
plt.plot(X,Y)
plotPendiente(X,Y)
plt.show()

# %% [markdown]
# # ---------------------------------------------------------------

# %% [markdown]
# # ---------------------------------------------------------------

# %% [markdown]
# # Plotting curves from file data

# %% [markdown]
# * Plot datos de un archivo .txt
# * Diferentes formas de cargar archivos
# * Diferente formas de graficar datos de archivos

# %%
X,Y = [],[]
for line in open('data.txt','r'):
    valores = [float(s) for s in line.split(",")]
    X.append(valores[0])
    Y.append(valores[1])
plt.plot(X,Y)
plt.show()

# %%
with  open('data.txt','r') as f:
    X,Y,Z,A,B,C = zip(*[[float(s) for s in line.split(",")] for line in f ])
plt.plot(X,A)

plt.show()

# %%
data = np.loadtxt("data.txt", delimiter=',')
plt.plot(data[:,0],data[:,1])
plt.show()

# %%
data = np.loadtxt("data.txt", delimiter=',')
for columna in data.T:
    plt.plot(data[:,0],columna)
plt.show()

# %%
Xs=[]
X = [1,2,3,5,5,5]
Xs = X[1:] - X[:-1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-6f07f314d7ac> in <module>()
#       1 Xs=[]
#       2 X = [1,2,3,5,5,5]
# ----> 3 Xs = X[1:] - X[:-1]
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
X[1:]
# Out:
# [2, 3, 5, 5, 5]

# %%
X[:-1]
# Out:
# [1, 2, 3, 5, 5]

# %%
X = np.linspace(-3,3,100)
Y = np.exp(-X ** 2)
plt.plot(X,Y)
