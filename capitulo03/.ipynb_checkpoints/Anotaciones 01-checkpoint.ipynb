# %% [markdown]
# # Anotaciones

# %% [markdown]
# * Añadir un título
# * Que es LaTeX
# * Usar LaTeX-style
# * Etiqutas en los ejes
# * Añadir texto
# * Añadir flechas
# * Añadir leyendas y subtitulos
# * Añadir grid( cuadricula )
# * Añadir lineas
# * Añadir formas

# %%
import numpy as np
import matplotlib.pyplot as plt
X = np.linspace(-4, 4, 512)
Y = .25 * (X + 4.) * (X + 1.) * (X - 2.)
plt.title('Curva polinomica 1')
plt.plot(X, Y, c = 'r' , marker = '*' , ls='dotted')
plt.show()

# %% [markdown]
# LaTeX es un sistema de composición de textos, orientado especialmente a la creación de libros, documentos científicos y técnicos que contengan fórmulas matemáticas.

# %% [markdown]
#   \begin{align}
#     E_0 &= mc^2 \\
#     E &= \frac{mc^2}{\sqrt{1-\frac{v^2}{c^2}}}
#   \end{align}

# %% [markdown]
# $e^{i\pi} + 1 = 0$

# %% [markdown]
# $$\begin{matrix} a & b \\ c & d \end{matrix}$$

# %%
X = np.linspace(-4, 4, 1024)
Y = .25 * (X + 5.) * (X + 1.) * (X - 2.)
plt.title('$f(x)=\\frac{1}{4}(x+5)(x+1)(x-2)$')
plt.plot(X, Y, c = 'k')
plt.show()

# %% [markdown]
# # Etiquetar los ejes

# %%
X = np.linspace(-4, 4, 1024)
Y = .25 * (X + 4.) * (X + 1.) * (X - 2.)
plt.title('Curva de una aleta de un aereoplano KV873')
plt.xlabel('velocidad del aire - ') #eje x
plt.ylabel('Resistencia Total') # ejey
plt.plot(X, Y, c = 'k')
plt.show()

# %%
X = np.linspace(-4, 4, 1024)
Y = .25 * (X + 4.) * (X + 1.) * (X - 2.)
plt.text(1, 5, 'El minimo')
plt.plot(X, Y, c = 'k')
plt.show()

# %%
X = np.linspace(-4, 4, 1024)
Y = .25 * (X + 4.) * (X + 1.) * (X - 2.)
box = {
'facecolor' : '.8',
'edgecolor' : 'r',
'alpha': 0.9,
'boxstyle' : 'round' #square'
}
plt.text(-0.1, -0.20, 'minimo', bbox = box)#bbox define varios parametros
plt.plot(X, Y, c='k')
plt.show()

# %% [markdown]
# # Añadiendo flechas

# %%
X = np.linspace(-4, 4, 1024)
Y = .25 * (X + 4.) * (X + 1.) * (X - 2.)
plt.annotate('minimo',
            ha = 'center', va = 'bottom',
            xytext = (-1.5, 3.),
            xy = (0.75, -2.7), #punto minimo 
            arrowprops = { 'facecolor' : 'r', 'shrink' :0.005 ,'ArrowStyle':'fancy' }) # estilo
plt.plot(X, Y)
plt.show()

# %% [markdown]
# # Añadiendo leyendas

# %%
X = np.linspace(0, 6, 1024)
Y1 = np.sin(X)
Y2 = np.cos(X)
plt.title('ejemplo de leyendas en matplotlib')
plt.xlabel('X')
plt.ylabel('Y')
plt.plot(X, Y1, c = 'k', lw = 3., label = 'sin(X) -- ')
plt.plot(X, Y2, c = '.5', lw = 3., ls = '--', label = 'cos(X) --')
plt.legend(shadow = True) #'loc':'best' 'lower left',
plt.show()

# %% [markdown]
# # Añadir la cuadricula

# %%
X = np.linspace(-4, 4, 1024)
Y = .25 * (X + 4.) * (X + 1.) * (X - 2.)
plt.plot(X, Y, c = 'k')
#plt.grid()
plt.grid(True, lw = 3, ls = '--', c = '.75')
plt.show()

# %% [markdown]
# # Scalas

# %% [markdown]
# Escala de igual manera los ejes X  y los ejes Y

# %%
N = 8
for i in range(N):
    plt.gca().add_line(plt.Line2D((0, i), (N - i, 0), color = '.75')) # crea la linea pero no aparecera hasta que explicitamente la 
    #haga aparecer usando gca
plt.grid(True)
plt.axis('scaled')
plt.show()

# %%
plt.gca().add_line(plt.Line2D((0,1),(5,5), color = '0.2'))
plt.axis('tight')
plt.show()

# %% [markdown]
# # Formas y figuras

# %%
import matplotlib.patches as patches
import matplotlib.pyplot as plt
# circulo
forma = patches.Circle((0, 0), radius = 1., color = '.75')
plt.gca().add_patch(forma)
# Rectangulo
forma = patches.Rectangle((2.5, -.5), 2., 1., color = '.75')
plt.gca().add_patch(forma)
# Elipse
forma = patches.Ellipse((0, -2.), 2., 1., angle = 40., color =    '.75')
plt.gca().add_patch(forma)
# formas de paralelogramo
forma = patches.FancyBboxPatch((2.5, -2.5), 2., 1., boxstyle ='round4', color = '.75')
#(either 'larrow', 'rarrow', 'round', 'round4', 'roundtooth', 'sawtooth',or 'square')
plt.gca().add_patch(forma)
# Display all
plt.grid(True)
plt.axis('scaled')
plt.show()

# %% [markdown]
# # Poligonos

# %%
import numpy as np
import matplotlib.patches as patches
import matplotlib.pyplot as plt
theta = np.linspace(0, 2 * np.pi, 6)
puntos = np.vstack((np.cos(theta), np.sin(theta))).transpose()
plt.gca().add_patch(patches.Polygon(puntos, color = '.75'))
plt.grid(True)
plt.axis('scaled')
plt.show()

# %% [markdown]
# # atributos de figuras

# %%
? np.vstack

# %%
import numpy as np
import matplotlib.patches as patches
import matplotlib.pyplot as plt
theta = np.linspace(0, 2 * np.pi, 6)
points = np.vstack((np.cos(theta), np.sin(theta))).transpose()
plt.gca().add_patch(plt.Circle((0, 0), radius = 1., color ='.75'))
plt.gca().add_patch(plt.Polygon(points, closed=None, fill=None,lw = 3., ls = 'dashed', edgecolor = 'r'))
plt.grid(True)
plt.axis('scaled')
plt.show()

# %%
a = np.array([[1], [2], [3]])
b = np.array([[5], [5], [4]])
np.vstack((a,b))
# Out:
# array([[1],
#        [2],
#        [3],
#        [5],
#        [5],
#        [4]])

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
X = np.linspace(-15, 15, 1024)
Y = np.sinc(X)
ax = plt.axes()
ax.xaxis.set_major_locator(ticker.MultipleLocator(5)) #divisiones en los labels
ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.25)) # divisiones menores de la regla
plt.plot(X, Y, c = 'k')
plt.show()

# %%
X = np.linspace(-15, 15, 1024)
Y = np.sinc(X)
ax = plt.axes()
ax.yaxis.set_major_locator(ticker.MultipleLocator(0.5)) # en y
ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.01))# en y
plt.grid(True, which='both') # para ambos ejes
#plt.grid()
plt.plot(X, Y)
plt.show()

# %%
import numpy as np
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt
lista_nombres = ('Omar', 'Serguey', 'Max', 'Zhou', 'alex')
lista_valores = np.random.randint(0, 99, size = len(lista_nombres))
pos_lista = np.arange(len(lista_nombres))
ax = plt.axes()
ax.xaxis.set_major_locator(ticker.FixedLocator((pos_lista)))
ax.xaxis.set_major_formatter(ticker.FixedFormatter((lista_nombres)))
plt.bar(pos_lista, lista_valores, color = '.75', align = 'center', edgecolor ='k')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
lista_nombres = ('Omar', 'Serguey', 'Max', 'Zhou', 'alex')
lista_valores = np.random.randint(0, 99, size = len(lista_nombres))
pos_lista = np.arange(len(lista_nombres))
plt.bar(pos_lista, lista_valores, color = '.75', align = 'center',edgecolor ='k')
plt.xticks(pos_lista, lista_nombres) #esta funcion da un arreglo a las etiquetas
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
def make_label(value, pos):
    return '%0.1f%%' % (100. * value)
ax = plt.axes()
ax.xaxis.set_major_formatter(ticker.FuncFormatter(make_label))
X = np.linspace(0, 1, 256)
plt.plot(X, np.exp(-10 * X), c ='k')
plt.plot(X, np.exp(-5 * X), c= 'k', ls = '--')
plt.show()

# %%
import datetime

# %%
fecha_inicio = datetime.datetime(2020, 1, 1)
def make_label(valor, pos):
    time = fecha_inicio + datetime.timedelta(days = 365 * valor)
    return time.strftime('%b %y')
ax = plt.axes()
ax.xaxis.set_major_formatter(ticker.FuncFormatter(make_label))
X = np.linspace(0, 1, 256)
plt.plot(X, np.exp(-10 * X), c = 'k')
plt.plot(X, np.exp(-5 * X), c = 'k', ls = '--')
labels = ax.get_xticklabels()
plt.setp(labels, rotation = 90.)
plt.show()
